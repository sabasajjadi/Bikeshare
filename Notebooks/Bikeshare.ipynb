# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv("hourly.csv")

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
print("Our data have {} rows and {} columns" .format(df.shape[0], df.shape[1]))
# Out:
# Our data have 17379 rows and 17 columns

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# instant       False
# dteday        False
# season        False
# yr            False
# mnth          False
# hr            False
# holiday       False
# weekday       False
# workingday    False
# weathersit    False
# temp          False
# atemp         False
# hum           False
# windspeed     False
# casual        False
# registered    False
# cnt           False
# dtype: bool

# %% [markdown]
# __No missing or NAN values are present in our data.__

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
fig, ax =plt.subplots(figsize=(15, 15))
plt.title("Correlation Plot")
sns.heatmap(df.corr(), mask=np.zeros_like(df.corr(), dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot=True,linewidths=3)
plt.show()

# %%
#removing irrelevant fetaures basedon correlation
columns=["instant", "dteday", "yr", "mnth", "hr", "holiday", "weekday", "workingday", "temp"]

df= df.drop(columns, axis=1)

# %%
print("After removing some irrelevant features our data have {} rows and {} columns" .format(df.shape[0], df.shape[1]))
# Out:
# After removing some irrelevant features our data have 17379 rows and 8 columns

# %%
fig, ax =plt.subplots(figsize=(15, 15))
plt.title("Correlation Plot")
sns.heatmap(df.corr(), mask=np.zeros_like(df.corr(), dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot=True,linewidths=3)
plt.show()

# %%
sns.countplot(df["season"], palette="Set3" )

# %%
sns.countplot(df["weathersit"], palette="Set3")

# %%
sns.jointplot(x="season",y="cnt",data=df, color='brown', size=12,kind="reg")
# Out:
# /Users/sabasajjadi/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x="weathersit",y="cnt",data=df, color='brown', size=12,kind="reg")

# %%
sns.jointplot(x="atemp",y="cnt",data=df, color='brown', size=12,kind="reg")

# %%
sns.jointplot(x="hum",y="cnt",data=df, color='brown', size=12,kind="reg")

# %%
sns.jointplot(x="windspeed",y="cnt",data=df, color='brown', size=12,kind="reg")

# %%
sns.jointplot(x="casual",y="cnt",data=df, color='brown', size=12,kind="reg")

# %%
sns.jointplot(x="registered",y="cnt",data=df, color='brown', size=12,kind="reg")

# %%
# splitting features into dependent(y) and independent features(X)

X = df.drop("cnt",axis=1)
y = df["cnt"]

# %%
# normalizing independent features to a single scale using standard scalar

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
X = scaler.transform(X)
X = pd.DataFrame(X)
X.columns = ['season', 'weathersit', 'atemp', 'hum', 'windspeed', 'casual','registered']

# %%
# Splitting data into train and test sample using 70% data for training and 30% data for testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# __Training a Linear Regression Model:__

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("The Intercept for the given Liner Regresssion is = ", lm.intercept_)
# Out:
# The Intercept for the given Liner Regresssion is =  189.46308763450142

# %%
print("Coefficients are as follows:")
a=list(lm.coef_)
for m,n in zip(X,a):
     print(m,"=",n)
# Out:
# Coefficients are as follows:
# season = -3.1933607531180314e-14
# weathersit = 5.2764572831787255e-15
# atemp = -6.857004316770456e-14
# hum = -1.259412546184036e-14
# windspeed = 2.5176315305270137e-14
# casual = 49.30361184341792
# registered = 151.35293124708807

# %%
# making predictions
y_pred_test = lm.predict(X_test)
y_pred_train = lm.predict(X_train)

# %%
from sklearn import metrics

# %%
# calculating Root Mean Square Error for evaluation of model
RMSE_train = np.sqrt( metrics.mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))

# %%
print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 1.4214726689427883e-13
# RMSE for test set is 1.394245944749625e-13

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test})
df.head()
# Out:
#        Actual  Predicted
# 14794     352      352.0
# 7746       81       81.0
# 9286      159      159.0
# 5485      313      313.0
# 1682      217      217.0

# %%
df1 = df.head(50)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.xticks([])
plt.show()

# %% [markdown]
# __Training a Random-Forest Regression Model:__

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# Train the model on training data
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
# making predictions
y_pred_test = rf.predict(X_test)
y_pred_train = rf.predict(X_train)

# %%
# calculating Root Mean Square Error for evaluating model
RMSE_train = np.sqrt( metrics.mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test))

# %%
print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 1.0255508924297316
# RMSE for test set is 1.9960447469334561

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test})
df.head()
# Out:
#        Actual  Predicted
# 14794     352    353.313
# 7746       81     81.054
# 9286      159    159.975
# 5485      313    312.951
# 1682      217    218.190

# %%
df1 = df.head(50)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.xticks([])
plt.show()
